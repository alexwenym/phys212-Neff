# %%
import getdist
from cobaya.yaml import yaml_load_file
from cobaya.run import run

info_from_yaml = yaml_load_file("gaussian.yaml")

# %%
updated_info, sampler = run(info_from_yaml, force=True)

# %%
gd_sample = sampler.products(to_getdist=True)["sample"]

# Analyze and plot
mean = gd_sample.getMeans()[:2]
covmat = gd_sample.getCovMat().matrix[:2, :2]
print("Mean:")
print(mean)
print("Covariance matrix:")
print(covmat)
#%matplotlib inline 
import getdist.plots as gdplt

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(gd_sample, ["a", "b"], filled=True)
# Out:
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'
# [root] *WARNING* outlier fraction 0.026785714285714284
# Mean:
# [0.19396586 0.01588338]
# Covariance matrix:
# [[0.09412851 0.03671651]
#  [0.03671651 0.17516954]]
